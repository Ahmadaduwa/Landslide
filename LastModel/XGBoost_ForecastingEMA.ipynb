# %%
# %% 
# ====================================================================
# 1. IMPORTS & CONFIGURATION after fix labels
# ====================================================================
import os
import glob
import time
import json
import random
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Advanced Models
import optuna 
import xgboost as xgb
import shap

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score

import warnings
warnings.filterwarnings('ignore')

class Config:
    DATA_DIR = "./dataEMA/"
    MODEL_DIR = "./model/xgboost_stratified_ema/"
    
    # [0, 60...]
    HORIZONS = [0, 30, 60, 180, 360, 720, 1440]  
    
    FEATURE_COLS = [
        'rain', 'soil', 'temp', 'geo', 'humi',
        'rain_ema_60min','rain_ema_360min','rain_ema_720min','rain_ema_1440min',
        'soil_ema_240min','soil_ema_480min','soil_ema_720min','soil_ema_960min',
        'geo_ema_2min','geo_ema_4min','geo_ema_6min','geo_ema_8min',
        'soil_diff_1m','geo_diff_1m','rain_diff_1m',
        'soil_diff_1h','hour_sin','hour_cos'
    ]
    
    LABEL_COL = 'label'
    LABEL_MAP = {'normal': 0, 'warning': 1, 'critical': 2}
    
    # --- IMBALANCE HANDLING ---
    TARGET_SAMPLES = 10000  
    
    # --- OPTIMIZATION ---
    OPTUNA_TRIALS = 100      
    
    XGB_FIXED = {
        'objective': 'multi:softprob',
        'num_class': 3,
        'n_jobs': -1,
        'random_state': 42,
        'tree_method': 'hist',
        'early_stopping_rounds': 20
    }

cfg = Config()
if not os.path.exists(cfg.MODEL_DIR): os.makedirs(cfg.MODEL_DIR)
np.random.seed(42); random.seed(42)

def log(msg): print(f"[INFO] {time.strftime('%H:%M:%S')} - {msg}")
print("✅ Config Loaded.")

# %%
# ====================================================================
# 2. DATA LOADING & PRE-PROCESSING (Label First -> Sensor Last)
# ====================================================================
def load_and_prep_data():
    log("Scanning & Loading All Data...")
    files = glob.glob(os.path.join(cfg.DATA_DIR, "*.csv"))
    if not files: files = glob.glob(os.path.join(cfg.DATA_DIR, "**/*.csv"), recursive=True)
    
    dfs = []
    for f in files:
        try:
            df = pd.read_csv(f)
            df.columns = [str(c).lower().strip().replace('.1', '') for c in df.columns]
            
            rename_map = {
                'temperature':'temp', 'hum':'humi', 'humidity':'humi', 
                'devid':'devID', 'time':'timestamp', 'date':'timestamp'
            }
            new_cols = {c: rename_map[c] for c in df.columns if c in rename_map}
            if new_cols: df = df.rename(columns=new_cols)
            
            dfs.append(df)
            print(f"   + Loaded: {os.path.basename(f)} | Rows: {len(df)}")
        except Exception as e: 
            print(f"   ! Error loading {f}: {e}")
            
    if not dfs: return None
    
    full_df = pd.concat(dfs, ignore_index=True)
    
    # Clean & Sort
    if 'timestamp' in full_df.columns:
        full_df['timestamp'] = pd.to_datetime(full_df['timestamp'], errors='coerce')
        full_df = full_df.dropna(subset=['timestamp'])

    if 'devID' in full_df.columns and 'timestamp' in full_df.columns:
        full_df = full_df.sort_values(by=['devID', 'timestamp'], ascending=[True, True])
    
    # -----------------------------------------------------------
    # STEP 1: LABEL HANDLING 
    # -----------------------------------------------------------
    log("Processing Labels...")
    if cfg.LABEL_COL in full_df.columns:
        # A. เติม Null เป็น 'normal' ทันที
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].fillna('normal') 
        
        # B. แปลงเป็น String และ clean
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].astype(str).str.lower().str.strip()
        
        # C. จัดการ Text แปลกๆ ที่อาจหลุดมา
        full_df.loc[full_df[cfg.LABEL_COL] == '', cfg.LABEL_COL] = 'normal'
        full_df.loc[full_df[cfg.LABEL_COL] == 'nan', cfg.LABEL_COL] = 'normal'
        
        # D. Map เป็นตัวเลข 0, 1, 2
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].map(cfg.LABEL_MAP).fillna(0).astype(int)
    else:
        full_df[cfg.LABEL_COL] = 0

    # -----------------------------------------------------------
    # STEP 2: SENSOR IMPUTATION 
    # -----------------------------------------------------------
    log("Imputing Sensors (Forward & Backward Fill)...")
    
    # เลือกเฉพาะ Column ที่ไม่ใช่ Key (devID, timestamp) และไม่ใช่ Label
    cols_to_fill = [c for c in full_df.columns if c not in ['devID', 'timestamp', cfg.LABEL_COL]]
    
    if 'devID' in full_df.columns:
        # Assign กลับไปเฉพาะ Column ที่เลือก (devID จะไม่หาย)
        full_df[cols_to_fill] = full_df.groupby('devID')[cols_to_fill].ffill()
        full_df[cols_to_fill] = full_df.groupby('devID')[cols_to_fill].bfill()
    
    # Fallback: ถ้ายังมี NaN เหลือ ให้เติม 0
    full_df = full_df.fillna(0)
        
    return full_df.reset_index(drop=True)

# %%
# ====================================================================
# 3. STRATIFIED SPLIT
# ====================================================================
def prepare_data_pipeline(df, feature_cols, horizon=0):
    log(f"Preparing Data Pipeline (Horizon: {horizon})...")
    df_work = df.copy()

    # 1. Create Target
    if horizon > 0:
        df_work['target'] = df_work.groupby('devID')[cfg.LABEL_COL].shift(-horizon)
    else:
        df_work['target'] = df_work[cfg.LABEL_COL]
        
    df_work = df_work.dropna(subset=['target'])
    
    # 2. STRATIFIED SPLIT
    valid_feats = [c for c in feature_cols if c in df_work.columns]
    X = df_work[valid_feats].values
    y = df_work['target'].astype(int).values
    
    # Split 80/10/10
    X_temp, X_test, y_temp, y_test = train_test_split(
        X, y, test_size=0.10, stratify=y, random_state=42
    )
    
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=0.10, stratify=y_temp, random_state=42
    )
    
    print(f"\n📊 --- Stratified Split Stats (Horizon +{horizon}) ---")
    def print_count(name, y_data):
        c = Counter(y_data)
        print(f"   📌 {name:10s} | Rows: {len(y_data):<6} | 0: {c[0]:<5} 1: {c[1]:<5} 2: {c[2]:<5}")

    print_count("TRAIN", y_train)
    print_count("VAL", y_val)
    print_count("TEST", y_test)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

def balance_training_data(X_train, y_train):
    log("Applying Balancing to TRAIN set...")
    X_bal, y_bal = [], []
    for cls in np.unique(y_train):
        indices = np.where(y_train == cls)[0]
        count = len(indices)
        target = cfg.TARGET_SAMPLES
        if count == 0: continue
        
        if cls == 0 and count > target:
             chosen = np.random.choice(indices, target, replace=False)
        elif count < target:
             chosen = np.random.choice(indices, target, replace=True)
        else:
             chosen = indices
             
        X_bal.append(X_train[chosen])
        y_bal.append(y_train[chosen])
    
    X_bal = np.concatenate(X_bal)
    y_bal = np.concatenate(y_bal)
    
    perm = np.random.permutation(len(X_bal))
    return X_bal[perm], y_bal[perm]

# %%
# ====================================================================
# 4. VISUALIZATION & SHAP
# ====================================================================
def evaluate_set(y_true, y_pred, title):
    print(f"\n{'='*20} {title} {'='*20}")
    print(classification_report(y_true, y_pred, target_names=['Normal', 'Warning', 'Critical'], zero_division=0))
    
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1, 2])
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal', 'Warning', 'Critical'],
                yticklabels=['Normal', 'Warning', 'Critical'])
    plt.title(f"Confusion Matrix: {title}")
    plt.ylabel('Actual'); plt.xlabel('Predicted')
    plt.show()

def plot_feature_importance(model, feature_names):
    try:
        importance = model.feature_importances_
        fi_df = pd.DataFrame({'feature': feature_names, 'importance': importance})
        fi_df = fi_df.sort_values(by='importance', ascending=False).head(20)
        
        plt.figure(figsize=(10, 6))
        sns.barplot(x='importance', y='feature', data=fi_df, palette='viridis')
        plt.title('Top 20 Feature Importance (XGBoost Native)')
        plt.tight_layout()
        plt.show()
    except: pass

def run_shap_analysis(model, X_sample, feature_names, title_suffix=""):
    print(f"\n🧠 Running SHAP Analysis ({title_suffix})...")
    X_df = pd.DataFrame(X_sample, columns=feature_names)
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_df)
    
    plt.figure()
    shap.summary_plot(shap_values, X_df, plot_type="bar", show=False)
    plt.title(f"SHAP Global Importance - {title_suffix}")
    plt.show()
    
    if isinstance(shap_values, list) and len(shap_values) > 2:
        plt.figure()
        shap.summary_plot(shap_values[2], X_df, show=False)
        plt.title(f"SHAP Values (Critical Class) - {title_suffix}")
        plt.show()
    else:
        plt.figure()
        shap.summary_plot(shap_values, X_df, show=False)
        plt.show()

# ====================================================================
# 5. OPTIMIZATION 
# ====================================================================
def objective(trial, X_tr, y_tr, X_val, y_val):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5)
    }
    model = xgb.XGBClassifier(**cfg.XGB_FIXED, **params)
    model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], verbose=False)
    preds = model.predict(X_val)
    return f1_score(y_val, preds, average='macro', zero_division=0)

# %%
# ====================================================================
# 6. MAIN EXECUTION
# ====================================================================
def main():
    # 1. Load Data
    df_raw = load_and_prep_data()
    if df_raw is None: return

    if not cfg.FEATURE_COLS:
        cfg.FEATURE_COLS = [c for c in df_raw.columns if c not in [cfg.LABEL_COL, 'timestamp', 'devID', 'target', 'is_test']]
    print(f"👉 Features Used: {len(cfg.FEATURE_COLS)}")
    
    for h in cfg.HORIZONS:
        print(f"\n{'='*50}\n🚀 HORIZON: +{h} Steps\n{'='*50}")
        
        # 2. Split (Stratified)
        X_train_raw, y_train, X_val_raw, y_val, X_test_raw, y_test = prepare_data_pipeline(df_raw, cfg.FEATURE_COLS, h)
        
        if len(X_train_raw) == 0: continue
        
        # 3. Scale (Fit on Train ONLY)
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_raw)
        X_val_scaled = scaler.transform(X_val_raw)
        X_test_scaled = scaler.transform(X_test_raw)
        
        joblib.dump(scaler, f"{cfg.MODEL_DIR}/scaler_h{h}.save")
        
        # 4. Balance (Train Only)
        X_train_bal, y_train_bal = balance_training_data(X_train_scaled, y_train)
        
        # 5. Optimize
        log(f"Tuning Hyperparameters...")
        optuna.logging.set_verbosity(optuna.logging.WARNING)
        study = optuna.create_study(direction='maximize')
        study.optimize(lambda t: objective(t, X_train_bal, y_train_bal, X_val_scaled, y_val), n_trials=cfg.OPTUNA_TRIALS)
        
        best_params = study.best_params
        print(f"   🏆 Best Params: {best_params}")
        
        # 6. Final Train
        final_model = xgb.XGBClassifier(**cfg.XGB_FIXED, **best_params)
        final_model.fit(X_train_bal, y_train_bal, eval_set=[(X_val_scaled, y_val)], verbose=False)
        final_model.save_model(os.path.join(cfg.MODEL_DIR, f"xgb_strat_h{h}.json"))
        
        # 7. Evaluate
        print("\n🔎 Evaluating TRAIN Set (Balanced)...")
        evaluate_set(y_train_bal, final_model.predict(X_train_bal), f"TRAIN - H{h}")

        print("\n🔎 Evaluating VALIDATION Set...")
        evaluate_set(y_val, final_model.predict(X_val_scaled), f"VAL - H{h}")

        print("\n🔎 Evaluating TEST Set...")
        evaluate_set(y_test, final_model.predict(X_test_scaled), f"TEST - H{h}")
        
        # 8. Feature Importance & SHAP
        plot_feature_importance(final_model, cfg.FEATURE_COLS)
        
        shap_sample_size = min(500, len(X_test_scaled))
        if shap_sample_size > 0:
            idx = np.random.choice(len(X_test_scaled), shap_sample_size, replace=False)
            run_shap_analysis(final_model, X_test_scaled[idx], cfg.FEATURE_COLS, title_suffix=f"H{h}")

    print("\n✅ Process Completed.")

if __name__ == "__main__":
    main()
# Out:
# ✅ Config Loaded.
# [INFO] 16:41:58 - Scanning & Loading All Data...
#    + Loaded: label_105_EMA.csv | Rows: 20777
#    + Loaded: label_106_EMA.csv | Rows: 36593
#    + Loaded: label_107_EMA.csv | Rows: 27096
#    + Loaded: label_108_EMA.csv | Rows: 37817
#    + Loaded: label_109_EMA.csv | Rows: 26636
# [INFO] 16:41:59 - Processing Labels...
# [INFO] 16:42:00 - Imputing Sensors (Forward & Backward Fill)...
# 👉 Features Used: 23
#
# ==================================================
# 🚀 HORIZON: +0 Steps
# ==================================================
# [INFO] 16:42:00 - Preparing Data Pipeline (Horizon: 0)...
#
# 📊 --- Stratified Split Stats (Horizon +0) ---
#    📌 TRAIN      | Rows: 116193 | 0: 110806 1: 5131  2: 256
#    📌 VAL        | Rows: 12911  | 0: 12312 1: 570   2: 29
#    📌 TEST       | Rows: 14345  | 0: 13680 1: 633   2: 32
# [INFO] 16:42:00 - Applying Balancing to TRAIN set...
# [INFO] 16:42:00 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 332, 'learning_rate': 0.12764967461744897, 'max_depth': 6, 'subsample': 0.8661914412997783, 'colsample_bytree': 0.8969407149590076, 'min_child_weight': 7, 'gamma': 0.49542100373798204}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     12312
#      Warning       0.96      1.00      0.98       570
#     Critical       1.00      0.97      0.98        29
#
#     accuracy                           1.00     12911
#    macro avg       0.99      0.99      0.99     12911
# weighted avg       1.00      1.00      1.00     12911
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     13680
#      Warning       0.95      0.99      0.97       633
#     Critical       0.91      0.94      0.92        32
#
#     accuracy                           1.00     14345
#    macro avg       0.95      0.98      0.96     14345
# weighted avg       1.00      1.00      1.00     14345
# 🧠 Running SHAP Analysis (H0)...
# ==================================================
# 🚀 HORIZON: +30 Steps
# ==================================================
# [INFO] 16:44:07 - Preparing Data Pipeline (Horizon: 30)...
#
# 📊 --- Stratified Split Stats (Horizon +30) ---
#    📌 TRAIN      | Rows: 116072 | 0: 110685 1: 5131  2: 256
#    📌 VAL        | Rows: 12897  | 0: 12298 1: 570   2: 29
#    📌 TEST       | Rows: 14330  | 0: 13665 1: 633   2: 32
# [INFO] 16:44:07 - Applying Balancing to TRAIN set...
# [INFO] 16:44:07 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 467, 'learning_rate': 0.0482377391919909, 'max_depth': 8, 'subsample': 0.7269824605216214, 'colsample_bytree': 0.6375918207088236, 'min_child_weight': 2, 'gamma': 0.3703012136913491}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     12298
#      Warning       0.87      0.98      0.92       570
#     Critical       0.90      0.93      0.92        29
#
#     accuracy                           0.99     12897
#    macro avg       0.92      0.97      0.94     12897
# weighted avg       0.99      0.99      0.99     12897
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     13665
#      Warning       0.85      0.99      0.92       633
#     Critical       0.84      0.97      0.90        32
#
#     accuracy                           0.99     14330
#    macro avg       0.90      0.98      0.94     14330
# weighted avg       0.99      0.99      0.99     14330
# 🧠 Running SHAP Analysis (H30)...
# ==================================================
# 🚀 HORIZON: +60 Steps
# ==================================================
# [INFO] 16:48:07 - Preparing Data Pipeline (Horizon: 60)...
#
# 📊 --- Stratified Split Stats (Horizon +60) ---
#    📌 TRAIN      | Rows: 115950 | 0: 110563 1: 5131  2: 256
#    📌 VAL        | Rows: 12884  | 0: 12285 1: 570   2: 29
#    📌 TEST       | Rows: 14315  | 0: 13650 1: 633   2: 32
# [INFO] 16:48:07 - Applying Balancing to TRAIN set...
# [INFO] 16:48:07 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 368, 'learning_rate': 0.048764279245402484, 'max_depth': 10, 'subsample': 0.7178070528480499, 'colsample_bytree': 0.6235625269186434, 'min_child_weight': 4, 'gamma': 0.25833804317760617}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     12285
#      Warning       0.87      0.99      0.92       570
#     Critical       0.88      1.00      0.94        29
#
#     accuracy                           0.99     12884
#    macro avg       0.92      0.99      0.95     12884
# weighted avg       0.99      0.99      0.99     12884
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     13650
#      Warning       0.86      0.98      0.92       633
#     Critical       0.88      0.94      0.91        32
#
#     accuracy                           0.99     14315
#    macro avg       0.92      0.97      0.94     14315
# weighted avg       0.99      0.99      0.99     14315
# 🧠 Running SHAP Analysis (H60)...
# ==================================================
# 🚀 HORIZON: +180 Steps
# ==================================================
# [INFO] 16:53:18 - Preparing Data Pipeline (Horizon: 180)...
#
# 📊 --- Stratified Split Stats (Horizon +180) ---
#    📌 TRAIN      | Rows: 115464 | 0: 110077 1: 5131  2: 256
#    📌 VAL        | Rows: 12830  | 0: 12231 1: 570   2: 29
#    📌 TEST       | Rows: 14255  | 0: 13590 1: 633   2: 32
# [INFO] 16:53:18 - Applying Balancing to TRAIN set...
# [INFO] 16:53:18 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 227, 'learning_rate': 0.041510889087037844, 'max_depth': 10, 'subsample': 0.601375545107508, 'colsample_bytree': 0.6891778465757058, 'min_child_weight': 1, 'gamma': 1.1034968314387528}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     12231
#      Warning       0.87      0.99      0.92       570
#     Critical       0.90      0.90      0.90        29
#
#     accuracy                           0.99     12830
#    macro avg       0.92      0.96      0.94     12830
# weighted avg       0.99      0.99      0.99     12830
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     13590
#      Warning       0.86      0.99      0.92       633
#     Critical       0.82      1.00      0.90        32
#
#     accuracy                           0.99     14255
#    macro avg       0.89      0.99      0.94     14255
# weighted avg       0.99      0.99      0.99     14255
# 🧠 Running SHAP Analysis (H180)...
# ==================================================
# 🚀 HORIZON: +360 Steps
# ==================================================
# [INFO] 16:57:54 - Preparing Data Pipeline (Horizon: 360)...
#
# 📊 --- Stratified Split Stats (Horizon +360) ---
#    📌 TRAIN      | Rows: 114735 | 0: 109348 1: 5131  2: 256
#    📌 VAL        | Rows: 12749  | 0: 12150 1: 570   2: 29
#    📌 TEST       | Rows: 14165  | 0: 13500 1: 633   2: 32
# [INFO] 16:57:55 - Applying Balancing to TRAIN set...
# [INFO] 16:57:55 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 491, 'learning_rate': 0.1699839287650467, 'max_depth': 10, 'subsample': 0.7504354312190825, 'colsample_bytree': 0.6505902182499042, 'min_child_weight': 2, 'gamma': 0.25767128034383197}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     12150
#      Warning       0.88      0.99      0.93       570
#     Critical       0.90      0.93      0.92        29
#
#     accuracy                           0.99     12749
#    macro avg       0.93      0.97      0.95     12749
# weighted avg       0.99      0.99      0.99     12749
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     13500
#      Warning       0.85      0.99      0.92       633
#     Critical       0.91      0.94      0.92        32
#
#     accuracy                           0.99     14165
#    macro avg       0.92      0.97      0.95     14165
# weighted avg       0.99      0.99      0.99     14165
# 🧠 Running SHAP Analysis (H360)...
# ==================================================
# 🚀 HORIZON: +720 Steps
# ==================================================
# [INFO] 17:01:00 - Preparing Data Pipeline (Horizon: 720)...
#
# 📊 --- Stratified Split Stats (Horizon +720) ---
#    📌 TRAIN      | Rows: 113277 | 0: 107890 1: 5131  2: 256
#    📌 VAL        | Rows: 12587  | 0: 11988 1: 570   2: 29
#    📌 TEST       | Rows: 13985  | 0: 13320 1: 633   2: 32
# [INFO] 17:01:00 - Applying Balancing to TRAIN set...
# [INFO] 17:01:00 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 242, 'learning_rate': 0.09461636540473937, 'max_depth': 9, 'subsample': 0.6295531780669443, 'colsample_bytree': 0.6200425206347405, 'min_child_weight': 4, 'gamma': 0.3012588972380079}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     11988
#      Warning       0.88      0.99      0.94       570
#     Critical       0.93      0.93      0.93        29
#
#     accuracy                           0.99     12587
#    macro avg       0.94      0.97      0.95     12587
# weighted avg       0.99      0.99      0.99     12587
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     13320
#      Warning       0.87      0.99      0.93       633
#     Critical       0.93      0.88      0.90        32
#
#     accuracy                           0.99     13985
#    macro avg       0.93      0.95      0.94     13985
# weighted avg       0.99      0.99      0.99     13985
# 🧠 Running SHAP Analysis (H720)...
# ==================================================
# 🚀 HORIZON: +1440 Steps
# ==================================================
# [INFO] 17:04:32 - Preparing Data Pipeline (Horizon: 1440)...
#
# 📊 --- Stratified Split Stats (Horizon +1440) ---
#    📌 TRAIN      | Rows: 110361 | 0: 104974 1: 5131  2: 256
#    📌 VAL        | Rows: 12263  | 0: 11664 1: 570   2: 29
#    📌 TEST       | Rows: 13625  | 0: 12960 1: 633   2: 32
# [INFO] 17:04:33 - Applying Balancing to TRAIN set...
# [INFO] 17:04:33 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 407, 'learning_rate': 0.11446690888185555, 'max_depth': 8, 'subsample': 0.8070392108240746, 'colsample_bytree': 0.6329680627002783, 'min_child_weight': 1, 'gamma': 0.0034822118448297815}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     11664
#      Warning       0.91      1.00      0.95       570
#     Critical       0.93      0.97      0.95        29
#
#     accuracy                           1.00     12263
#    macro avg       0.95      0.99      0.97     12263
# weighted avg       1.00      1.00      1.00     12263
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     12960
#      Warning       0.87      0.99      0.93       633
#     Critical       0.94      0.94      0.94        32
#
#     accuracy                           0.99     13625
#    macro avg       0.94      0.97      0.95     13625
# weighted avg       0.99      0.99      0.99     13625
# 🧠 Running SHAP Analysis (H1440)...
# ✅ Process Completed.
