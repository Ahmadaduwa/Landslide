# %%
# %% 
# ====================================================================
# 1. IMPORTS & CONFIGURATION 
# ====================================================================
import os
import glob
import time
import json
import random
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Advanced Models
import optuna 
from sklearn.svm import SVC # <--- CHANGED: Use SVM
import shap

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score

import warnings
warnings.filterwarnings('ignore')

class Config:
    DATA_DIR = "./dataMA/"
    MODEL_DIR = "./model/svm_stratified/" # <--- CHANGED: Path
    
    # [0, 60...]
    HORIZONS = [0, 30, 60, 180, 360, 720, 1440]   
    
    FEATURE_COLS = [
        'rain', 'soil', 'temp', 'geo', 'humi', 
        'rain_ma_1h','rain_ma_6h','rain_ma_12h','rain_ma_24h',
        'soil_ma_4h','soil_ma_8h','soil_ma_12h','soil_ma_16h',
        'geo_ma_2m','geo_ma_4m','geo_ma_6m','geo_ma_8m',
        'soil_diff_1m','geo_diff_1m','rain_diff_1m',
        'soil_diff_1h','hour_sin','hour_cos'
    ]
    
    LABEL_COL = 'label'
    LABEL_MAP = {'normal': 0, 'warning': 1, 'critical': 2}
    
    # --- IMBALANCE HANDLING ---
    TARGET_SAMPLES = 10000
    
    # --- OPTIMIZATION ---
    OPTUNA_TRIALS = 10      
    
    # SVM Fixed Parameters
    SVM_FIXED = {
        'probability': True,   # เพื่อให้คำนวณ SHAP และ Softprob ได้
        'random_state': 42,
        'class_weight': None   # เรา Balance ข้อมูลเองแล้ว set เป็น None ได้
    }

cfg = Config()
if not os.path.exists(cfg.MODEL_DIR): os.makedirs(cfg.MODEL_DIR)
np.random.seed(42); random.seed(42)

def log(msg): print(f"[INFO] {time.strftime('%H:%M:%S')} - {msg}")
print("✅ Config Loaded (SVM Mode).")

# %%
# ====================================================================
# 2. DATA LOADING & PRE-PROCESSING (Label First -> Sensor Last)
# ====================================================================
def load_and_prep_data():
    log("Scanning & Loading All Data...")
    files = glob.glob(os.path.join(cfg.DATA_DIR, "*.csv"))
    if not files: files = glob.glob(os.path.join(cfg.DATA_DIR, "**/*.csv"), recursive=True)
    
    dfs = []
    for f in files:
        try:
            df = pd.read_csv(f)
            df.columns = [str(c).lower().strip().replace('.1', '') for c in df.columns]
            
            rename_map = {
                'temperature':'temp', 'hum':'humi', 'humidity':'humi', 
                'devid':'devID', 'time':'timestamp', 'date':'timestamp'
            }
            new_cols = {c: rename_map[c] for c in df.columns if c in rename_map}
            if new_cols: df = df.rename(columns=new_cols)
            
            dfs.append(df)
            print(f"   + Loaded: {os.path.basename(f)} | Rows: {len(df)}")
        except Exception as e: 
            print(f"   ! Error loading {f}: {e}")
            
    if not dfs: return None
    
    full_df = pd.concat(dfs, ignore_index=True)
    
    # Clean & Sort
    if 'timestamp' in full_df.columns:
        full_df['timestamp'] = pd.to_datetime(full_df['timestamp'], errors='coerce')
        full_df = full_df.dropna(subset=['timestamp'])

    if 'devID' in full_df.columns and 'timestamp' in full_df.columns:
        full_df = full_df.sort_values(by=['devID', 'timestamp'], ascending=[True, True])
    
    # -----------------------------------------------------------
    # STEP 1: LABEL HANDLING 
    # -----------------------------------------------------------
    log("Processing Labels...")
    if cfg.LABEL_COL in full_df.columns:
        # A. เติม Null เป็น 'normal' ทันที
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].fillna('normal') 
        
        # B. แปลงเป็น String และ clean
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].astype(str).str.lower().str.strip()
        
        # C. จัดการ Text แปลกๆ
        full_df.loc[full_df[cfg.LABEL_COL] == '', cfg.LABEL_COL] = 'normal'
        full_df.loc[full_df[cfg.LABEL_COL] == 'nan', cfg.LABEL_COL] = 'normal'
        
        # D. Map เป็นตัวเลข
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].map(cfg.LABEL_MAP).fillna(0).astype(int)
    else:
        full_df[cfg.LABEL_COL] = 0

    # -----------------------------------------------------------
    # STEP 2: SENSOR IMPUTATION 
    # -----------------------------------------------------------
    log("Imputing Sensors (Forward & Backward Fill)...")
    
    cols_to_fill = [c for c in full_df.columns if c not in ['devID', 'timestamp', cfg.LABEL_COL]]
    
    if 'devID' in full_df.columns:
        full_df[cols_to_fill] = full_df.groupby('devID')[cols_to_fill].ffill()
        full_df[cols_to_fill] = full_df.groupby('devID')[cols_to_fill].bfill()
    
    full_df = full_df.fillna(0)
        
    return full_df.reset_index(drop=True)

# %%
# ====================================================================
# 3. STRATIFIED SPLIT
# ====================================================================
def prepare_data_pipeline(df, feature_cols, horizon=0):
    log(f"Preparing Data Pipeline (Horizon: {horizon})...")
    df_work = df.copy()

    # 1. Create Target
    if horizon > 0:
        df_work['target'] = df_work.groupby('devID')[cfg.LABEL_COL].shift(-horizon)
    else:
        df_work['target'] = df_work[cfg.LABEL_COL]
        
    df_work = df_work.dropna(subset=['target'])
    
    # 2. STRATIFIED SPLIT
    valid_feats = [c for c in feature_cols if c in df_work.columns]
    X = df_work[valid_feats].values
    y = df_work['target'].astype(int).values
    
    X_temp, X_test, y_temp, y_test = train_test_split(
        X, y, test_size=0.10, stratify=y, random_state=42
    )
    
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=0.11111, stratify=y_temp, random_state=42
    )
    
    print(f"\n📊 --- Stratified Split Stats (Horizon +{horizon}) ---")
    def print_count(name, y_data):
        c = Counter(y_data)
        print(f"   📌 {name:10s} | Rows: {len(y_data):<6} | 0: {c[0]:<5} 1: {c[1]:<5} 2: {c[2]:<5}")

    print_count("TRAIN", y_train)
    print_count("VAL", y_val)
    print_count("TEST", y_test)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

def balance_training_data(X_train, y_train):
    log("Applying Balancing to TRAIN set...")
    X_bal, y_bal = [], []
    for cls in np.unique(y_train):
        indices = np.where(y_train == cls)[0]
        count = len(indices)
        target = cfg.TARGET_SAMPLES
        if count == 0: continue
        
        if cls == 0 and count > target:
             chosen = np.random.choice(indices, target, replace=False)
        elif count < target:
             chosen = np.random.choice(indices, target, replace=True)
        else:
             chosen = indices
             
        X_bal.append(X_train[chosen])
        y_bal.append(y_train[chosen])
    
    X_bal = np.concatenate(X_bal)
    y_bal = np.concatenate(y_bal)
    
    perm = np.random.permutation(len(X_bal))
    return X_bal[perm], y_bal[perm]

# %%
# ====================================================================
# 4. VISUALIZATION & SHAP (Adapted for SVM)
# ====================================================================
def evaluate_set(y_true, y_pred, title):
    print(f"\n{'='*20} {title} {'='*20}")
    print(classification_report(y_true, y_pred, target_names=['Normal', 'Warning', 'Critical'], zero_division=0))
    
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1, 2])
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal', 'Warning', 'Critical'],
                yticklabels=['Normal', 'Warning', 'Critical'])
    plt.title(f"Confusion Matrix: {title}")
    plt.ylabel('Actual'); plt.xlabel('Predicted')
    plt.show()

def run_shap_analysis_svm(model, X_train_sample, X_test_sample, feature_names, title_suffix=""):
    """
    SHAP for SVM: Uses KernelExplainer (Model Agnostic)
    Note: It is much slower than TreeExplainer, so we need to use a background sample.
    """
    print(f"\n🧠 Running SHAP Analysis for SVM ({title_suffix})...")
    try:
        # ใช้ KMeans เพื่อสรุป background data (ช่วยให้เร็วขึ้น) หรือใช้ sample เล็กๆ
        # เนื่องจาก SVM ช้ามาก เราจะใช้ background sample แค่ 50 ตัวอย่าง
        background = shap.sample(X_train_sample, 50) 
        
        # KernelExplainer ต้องการ function predict_proba
        explainer = shap.KernelExplainer(model.predict_proba, background)
        
        # คำนวณ SHAP values บน Test sample (ใช้ sample เล็กๆ เช่นกัน)
        shap_values = explainer.shap_values(X_test_sample, nsamples=100)
        
        X_test_df = pd.DataFrame(X_test_sample, columns=feature_names)

        # Plot 1: Summary Bar
        print("   👉 SHAP Summary Plot")
        plt.figure()
        shap.summary_plot(shap_values, X_test_df, plot_type="bar", show=False)
        plt.title(f"SHAP Global Importance - {title_suffix}")
        plt.show()
        
        # Plot 2: Beeswarm for Critical Class
        # shap_values สำหรับ multiclass จะเป็น list [class0, class1, class2]
        if isinstance(shap_values, list) and len(shap_values) > 2:
            print("   👉 SHAP Beeswarm Plot (Critical Class)")
            plt.figure()
            shap.summary_plot(shap_values[2], X_test_df, show=False)
            plt.title(f"SHAP Values (Critical Class) - {title_suffix}")
            plt.show()
            
    except Exception as e:
        print(f"⚠️ Could not run SHAP: {e}")

# ====================================================================
# 5. OPTIMIZATION (SVM)
# ====================================================================
def objective(trial, X_tr, y_tr, X_val, y_val):
    # Hyperparameters for SVM
    c_val = trial.suggest_float("C", 0.1, 100.0, log=True)
    gamma_val = trial.suggest_categorical("gamma", ["scale", "auto"])
    kernel_val = trial.suggest_categorical("kernel", ["rbf", "poly"]) # Linear ตัดออกเพราะช้าและอาจไม่แม่นยำพอกับข้อมูลนี้
    
    # สร้างโมเดล
    model = SVC(
        C=c_val,
        gamma=gamma_val,
        kernel=kernel_val,
        **cfg.SVM_FIXED
    )
    
    # Train (ระวัง: SVM ช้ามากกับข้อมูลใหญ่)
    model.fit(X_tr, y_tr)
    
    preds = model.predict(X_val)
    return f1_score(y_val, preds, average='macro', zero_division=0)

# %%
# ====================================================================
# 6. MAIN EXECUTION
# ====================================================================
def main():
    # 1. Load Data
    df_raw = load_and_prep_data()
    if df_raw is None: return

    if not cfg.FEATURE_COLS:
        cfg.FEATURE_COLS = [c for c in df_raw.columns if c not in [cfg.LABEL_COL, 'timestamp', 'devID', 'target', 'is_test']]
    print(f"👉 Features Used: {len(cfg.FEATURE_COLS)}")
    
    for h in cfg.HORIZONS:
        print(f"\n{'='*50}\n🚀 HORIZON: +{h} Steps\n{'='*50}")
        
        # 2. Split
        X_train_raw, y_train, X_val_raw, y_val, X_test_raw, y_test = prepare_data_pipeline(df_raw, cfg.FEATURE_COLS, h)
        if len(X_train_raw) == 0: continue
        
        # 3. Scale (SVM ต้องการ Scaling อย่างมาก!)
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_raw)
        X_val_scaled = scaler.transform(X_val_raw)
        X_test_scaled = scaler.transform(X_test_raw)
        
        joblib.dump(scaler, f"{cfg.MODEL_DIR}/scaler_h{h}.save")
        
        # 4. Balance
        X_train_bal, y_train_bal = balance_training_data(X_train_scaled, y_train)
        
        # 5. Optimize
        log(f"Tuning Hyperparameters (SVM takes time)...")
        optuna.logging.set_verbosity(optuna.logging.WARNING)
        study = optuna.create_study(direction='maximize')
        
        # ใช้ lambda เพื่อส่ง args
        study.optimize(lambda t: objective(t, X_train_bal, y_train_bal, X_val_scaled, y_val), n_trials=cfg.OPTUNA_TRIALS)
        
        best_params = study.best_params
        print(f"   🏆 Best Params: {best_params}")
        
        # 6. Final Train
        log("Training Final SVM Model...")
        final_model = SVC(**best_params, **cfg.SVM_FIXED)
        final_model.fit(X_train_bal, y_train_bal)
        
        # Save Model (Use joblib for sklearn models)
        joblib.dump(final_model, os.path.join(cfg.MODEL_DIR, f"svm_strat_h{h}.pkl"))
        
        # 7. Evaluate
        print("\n🔎 Evaluating TRAIN Set (Balanced)...")
        evaluate_set(y_train_bal, final_model.predict(X_train_bal), f"TRAIN - H{h}")

        print("\n🔎 Evaluating VALIDATION Set...")
        evaluate_set(y_val, final_model.predict(X_val_scaled), f"VAL - H{h}")

        print("\n🔎 Evaluating TEST Set...")
        evaluate_set(y_test, final_model.predict(X_test_scaled), f"TEST - H{h}")
        
        # 8. Feature Importance (Only for Linear, skip for RBF/Poly)
        if best_params.get('kernel') == 'linear':
            print("Note: Feature importance plot is available for Linear Kernel only.")
            # (Code for linear coef plotting omitted for brevity as RBF is usually preferred)
        else:
            print("Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).")

        # 9. SHAP (Sampled)
        # สุ่ม Test set 50 ตัวอย่างมาทำ SHAP (เยอะกว่านี้จะช้ามากสำหรับ KernelExplainer)
        shap_sample_size = min(50, len(X_test_scaled))
        if shap_sample_size > 0:
            idx = np.random.choice(len(X_test_scaled), shap_sample_size, replace=False)
            # ต้องส่ง X_train_bal ไปเป็น Background data ด้วย
            run_shap_analysis_svm(final_model, X_train_bal, X_test_scaled[idx], cfg.FEATURE_COLS, title_suffix=f"H{h}")

    print("\n✅ Process Completed.")

if __name__ == "__main__":
    main()
# Out:
# ✅ Config Loaded (SVM Mode).
# [INFO] 14:04:31 - Scanning & Loading All Data...
#    + Loaded: label_105_ma_prepared.csv | Rows: 20777
#    + Loaded: label_106_ma_prepared.csv | Rows: 36593
#    + Loaded: label_107_ma_prepared.csv | Rows: 27096
#    + Loaded: label_108_ma_prepared.csv | Rows: 37817
#    + Loaded: label_109_ma_prepared.csv | Rows: 26636
# [INFO] 14:04:33 - Processing Labels...
# [INFO] 14:04:33 - Imputing Sensors (Forward & Backward Fill)...
# 👉 Features Used: 23
#
# ==================================================
# 🚀 HORIZON: +0 Steps
# ==================================================
# [INFO] 14:04:33 - Preparing Data Pipeline (Horizon: 0)...
#
# 📊 --- Stratified Split Stats (Horizon +0) ---
#    📌 TRAIN      | Rows: 114759 | 0: 108700 1: 5541  2: 518
#    📌 VAL        | Rows: 14345  | 0: 13588 1: 692   2: 65
#    📌 TEST       | Rows: 14345  | 0: 13587 1: 693   2: 65
# [INFO] 14:04:33 - Applying Balancing to TRAIN set...
# [INFO] 14:04:33 - Tuning Hyperparameters (SVM takes time)...
#    🏆 Best Params: {'C': 40.503348526842075, 'gamma': 'auto', 'kernel': 'rbf'}
# [INFO] 14:13:18 - Training Final SVM Model...
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     13588
#      Warning       0.83      0.98      0.90       692
#     Critical       0.90      0.88      0.89        65
#
#     accuracy                           0.99     14345
#    macro avg       0.91      0.95      0.93     14345
# weighted avg       0.99      0.99      0.99     14345
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     13587
#      Warning       0.85      0.98      0.91       693
#     Critical       0.91      0.94      0.92        65
#
#     accuracy                           0.99     14345
#    macro avg       0.92      0.97      0.94     14345
# weighted avg       0.99      0.99      0.99     14345
# Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).
#
# 🧠 Running SHAP Analysis for SVM (H0)...
# 100%|██████████| 50/50 [00:42<00:00,  1.16it/s]
#    👉 SHAP Summary Plot
# ==================================================
# 🚀 HORIZON: +30 Steps
# ==================================================
# [INFO] 14:14:34 - Preparing Data Pipeline (Horizon: 30)...
#
# 📊 --- Stratified Split Stats (Horizon +30) ---
#    📌 TRAIN      | Rows: 114639 | 0: 108580 1: 5541  2: 518
#    📌 VAL        | Rows: 14330  | 0: 13573 1: 692   2: 65
#    📌 TEST       | Rows: 14330  | 0: 13572 1: 693   2: 65
# [INFO] 14:14:34 - Applying Balancing to TRAIN set...
# [INFO] 14:14:34 - Tuning Hyperparameters (SVM takes time)...
#    🏆 Best Params: {'C': 6.205333805857846, 'gamma': 'auto', 'kernel': 'rbf'}
# [INFO] 14:36:20 - Training Final SVM Model...
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.98      0.99     10000
#      Warning       0.98      0.98      0.98     10000
#     Critical       0.99      1.00      1.00     10000
#
#     accuracy                           0.99     30000
#    macro avg       0.99      0.99      0.99     30000
# weighted avg       0.99      0.99      0.99     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.97      0.98     13573
#      Warning       0.63      0.94      0.75       692
#     Critical       0.80      0.94      0.87        65
#
#     accuracy                           0.97     14330
#    macro avg       0.81      0.95      0.87     14330
# weighted avg       0.98      0.97      0.97     14330
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.97      0.98     13572
#      Warning       0.62      0.96      0.76       693
#     Critical       0.86      0.83      0.84        65
#
#     accuracy                           0.97     14330
#    macro avg       0.83      0.92      0.86     14330
# weighted avg       0.98      0.97      0.97     14330
# Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).
#
# 🧠 Running SHAP Analysis for SVM (H30)...
# 100%|██████████| 50/50 [00:44<00:00,  1.13it/s]
#    👉 SHAP Summary Plot
# ==================================================
# 🚀 HORIZON: +60 Steps
# ==================================================
# [INFO] 14:37:48 - Preparing Data Pipeline (Horizon: 60)...
#
# 📊 --- Stratified Split Stats (Horizon +60) ---
#    📌 TRAIN      | Rows: 114519 | 0: 108460 1: 5541  2: 518
#    📌 VAL        | Rows: 14315  | 0: 13558 1: 692   2: 65
#    📌 TEST       | Rows: 14315  | 0: 13557 1: 693   2: 65
# [INFO] 14:37:48 - Applying Balancing to TRAIN set...
# [INFO] 14:37:48 - Tuning Hyperparameters (SVM takes time)...
#    🏆 Best Params: {'C': 25.308542746524665, 'gamma': 'scale', 'kernel': 'rbf'}
# [INFO] 14:48:08 - Training Final SVM Model...
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.97      0.97     10000
#      Warning       0.97      0.93      0.95     10000
#     Critical       0.96      0.99      0.97     10000
#
#     accuracy                           0.97     30000
#    macro avg       0.97      0.97      0.97     30000
# weighted avg       0.97      0.97      0.97     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.97      0.98     13558
#      Warning       0.61      0.90      0.73       692
#     Critical       0.39      0.86      0.54        65
#
#     accuracy                           0.96     14315
#    macro avg       0.67      0.91      0.75     14315
# weighted avg       0.98      0.96      0.97     14315
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.97      0.98     13557
#      Warning       0.62      0.91      0.74       693
#     Critical       0.40      0.94      0.56        65
#
#     accuracy                           0.96     14315
#    macro avg       0.67      0.94      0.76     14315
# weighted avg       0.98      0.96      0.97     14315
# Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).
#
# 🧠 Running SHAP Analysis for SVM (H60)...
# 100%|██████████| 50/50 [01:26<00:00,  1.74s/it]
#    👉 SHAP Summary Plot
# ==================================================
# 🚀 HORIZON: +180 Steps
# ==================================================
# [INFO] 14:50:24 - Preparing Data Pipeline (Horizon: 180)...
#
# 📊 --- Stratified Split Stats (Horizon +180) ---
#    📌 TRAIN      | Rows: 114039 | 0: 107980 1: 5541  2: 518
#    📌 VAL        | Rows: 14255  | 0: 13498 1: 692   2: 65
#    📌 TEST       | Rows: 14255  | 0: 13497 1: 693   2: 65
# [INFO] 14:50:25 - Applying Balancing to TRAIN set...
# [INFO] 14:50:25 - Tuning Hyperparameters (SVM takes time)...
#    🏆 Best Params: {'C': 16.28873098030175, 'gamma': 'auto', 'kernel': 'poly'}
# [INFO] 15:11:45 - Training Final SVM Model...
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.98      0.98     10000
#      Warning       0.98      0.91      0.94     10000
#     Critical       0.93      1.00      0.96     10000
#
#     accuracy                           0.96     30000
#    macro avg       0.96      0.96      0.96     30000
# weighted avg       0.96      0.96      0.96     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.96      0.98     13498
#      Warning       0.59      0.85      0.69       692
#     Critical       0.24      0.86      0.37        65
#
#     accuracy                           0.96     14255
#    macro avg       0.61      0.89      0.68     14255
# weighted avg       0.97      0.96      0.96     14255
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.96      0.98     13497
#      Warning       0.59      0.87      0.70       693
#     Critical       0.24      0.91      0.37        65
#
#     accuracy                           0.95     14255
#    macro avg       0.61      0.91      0.68     14255
# weighted avg       0.97      0.95      0.96     14255
# Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).
#
# 🧠 Running SHAP Analysis for SVM (H180)...
# 100%|██████████| 50/50 [00:36<00:00,  1.36it/s]
#    👉 SHAP Summary Plot
# ==================================================
# 🚀 HORIZON: +360 Steps
# ==================================================
# [INFO] 15:16:13 - Preparing Data Pipeline (Horizon: 360)...
#
# 📊 --- Stratified Split Stats (Horizon +360) ---
#    📌 TRAIN      | Rows: 113319 | 0: 107260 1: 5541  2: 518
#    📌 VAL        | Rows: 14165  | 0: 13408 1: 692   2: 65
#    📌 TEST       | Rows: 14165  | 0: 13407 1: 693   2: 65
# [INFO] 15:16:13 - Applying Balancing to TRAIN set...
# [INFO] 15:16:13 - Tuning Hyperparameters (SVM takes time)...
#    🏆 Best Params: {'C': 30.352005501551243, 'gamma': 'auto', 'kernel': 'poly'}
# [INFO] 15:38:51 - Training Final SVM Model...
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.97      0.97     10000
#      Warning       0.97      0.88      0.92     10000
#     Critical       0.91      0.99      0.95     10000
#
#     accuracy                           0.95     30000
#    macro avg       0.95      0.95      0.95     30000
# weighted avg       0.95      0.95      0.95     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.97     13408
#      Warning       0.59      0.85      0.70       692
#     Critical       0.19      0.92      0.31        65
#
#     accuracy                           0.95     14165
#    macro avg       0.59      0.91      0.66     14165
# weighted avg       0.97      0.95      0.96     14165
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.96      0.98     13407
#      Warning       0.60      0.84      0.70       693
#     Critical       0.18      0.86      0.30        65
#
#     accuracy                           0.95     14165
#    macro avg       0.59      0.89      0.66     14165
# weighted avg       0.97      0.95      0.96     14165
# Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).
#
# 🧠 Running SHAP Analysis for SVM (H360)...
# 100%|██████████| 50/50 [00:25<00:00,  1.96it/s]
#    👉 SHAP Summary Plot
# ==================================================
# 🚀 HORIZON: +720 Steps
# ==================================================
# [INFO] 15:42:16 - Preparing Data Pipeline (Horizon: 720)...
#
# 📊 --- Stratified Split Stats (Horizon +720) ---
#    📌 TRAIN      | Rows: 111879 | 0: 105820 1: 5541  2: 518
#    📌 VAL        | Rows: 13985  | 0: 13228 1: 692   2: 65
#    📌 TEST       | Rows: 13985  | 0: 13227 1: 693   2: 65
# [INFO] 15:42:16 - Applying Balancing to TRAIN set...
# [INFO] 15:42:16 - Tuning Hyperparameters (SVM takes time)...
#    🏆 Best Params: {'C': 7.487837346527992, 'gamma': 'auto', 'kernel': 'rbf'}
# [INFO] 16:00:39 - Training Final SVM Model...
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       0.97      0.96      0.97     10000
#      Warning       0.95      0.75      0.84     10000
#     Critical       0.81      0.99      0.89     10000
#
#     accuracy                           0.90     30000
#    macro avg       0.91      0.90      0.90     30000
# weighted avg       0.91      0.90      0.90     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.97     13228
#      Warning       0.53      0.68      0.60       692
#     Critical       0.13      0.98      0.24        65
#
#     accuracy                           0.94     13985
#    macro avg       0.55      0.87      0.60     13985
# weighted avg       0.97      0.94      0.95     13985
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.95      0.97     13227
#      Warning       0.55      0.72      0.62       693
#     Critical       0.14      0.94      0.24        65
#
#     accuracy                           0.94     13985
#    macro avg       0.56      0.87      0.61     13985
# weighted avg       0.97      0.94      0.95     13985
# Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).
#
# 🧠 Running SHAP Analysis for SVM (H720)...
# 100%|██████████| 50/50 [02:14<00:00,  2.70s/it]
#    👉 SHAP Summary Plot
# ==================================================
# 🚀 HORIZON: +1440 Steps
# ==================================================
# [INFO] 16:04:45 - Preparing Data Pipeline (Horizon: 1440)...
#
# 📊 --- Stratified Split Stats (Horizon +1440) ---
#    📌 TRAIN      | Rows: 108999 | 0: 102940 1: 5541  2: 518
#    📌 VAL        | Rows: 13625  | 0: 12868 1: 692   2: 65
#    📌 TEST       | Rows: 13625  | 0: 12867 1: 693   2: 65
# [INFO] 16:04:45 - Applying Balancing to TRAIN set...
# [INFO] 16:04:45 - Tuning Hyperparameters (SVM takes time)...
#    🏆 Best Params: {'C': 50.077628673102296, 'gamma': 'auto', 'kernel': 'rbf'}
# [INFO] 16:22:26 - Training Final SVM Model...
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       0.99      0.98      0.98     10000
#      Warning       0.93      0.79      0.86     10000
#     Critical       0.83      0.97      0.89     10000
#
#     accuracy                           0.91     30000
#    macro avg       0.92      0.91      0.91     30000
# weighted avg       0.92      0.91      0.91     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.97      0.98     12868
#      Warning       0.55      0.75      0.64       692
#     Critical       0.27      0.94      0.43        65
#
#     accuracy                           0.96     13625
#    macro avg       0.61      0.89      0.68     13625
# weighted avg       0.97      0.96      0.96     13625
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.96      0.98     12867
#      Warning       0.54      0.76      0.63       693
#     Critical       0.28      0.94      0.43        65
#
#     accuracy                           0.95     13625
#    macro avg       0.60      0.89      0.68     13625
# weighted avg       0.97      0.95      0.96     13625
# Note: Native Feature Importance not available for non-linear kernels (RBF/Poly).
#
# 🧠 Running SHAP Analysis for SVM (H1440)...
# 100%|██████████| 50/50 [02:06<00:00,  2.53s/it]
#    👉 SHAP Summary Plot
# ✅ Process Completed.
