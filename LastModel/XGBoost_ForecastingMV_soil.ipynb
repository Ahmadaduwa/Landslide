# %%
# %% 
# ====================================================================
# 1. IMPORTS & CONFIGURATION after fix labels
# ====================================================================
import os
import glob
import time
import json
import random
import joblib
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from collections import Counter

# Advanced Models
import optuna 
import xgboost as xgb
import shap

# Sklearn
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import classification_report, confusion_matrix, f1_score

import warnings
warnings.filterwarnings('ignore')

class Config:
    DATA_DIR = "./data_soil/"
    MODEL_DIR = "./model/xgboost_stratified_soil/"
    
    # [0, 60...]
    HORIZONS = [0, 30, 60, 180, 360, 720, 1440]  
    
    FEATURE_COLS = [
        'soil','rain','temp','humi','geo','rain_ma_1h','rain_ma_6h',
        'rain_ma_12h','rain_ma_24h','soil_ma_4h','soil_ma_8h','soil_ma_12h',
        'soil_ma_16h','geo_ma_2m','geo_ma_4m','geo_ma_6m','geo_ma_8m',
        'soil_diff_1m','geo_diff_1m','rain_diff_1m','soil_diff_1h','hour_sin','hour_cos','sand','silt','clay'
    ]
    
    LABEL_COL = 'label'
    LABEL_MAP = {'normal': 0, 'warning': 1, 'critical': 2}
    
    # --- IMBALANCE HANDLING ---
    TARGET_SAMPLES = 10000  
    
    # --- OPTIMIZATION ---
    OPTUNA_TRIALS = 100      
    
    XGB_FIXED = {
        'objective': 'multi:softprob',
        'num_class': 3,
        'n_jobs': -1,
        'random_state': 42,
        'tree_method': 'hist',
        'early_stopping_rounds': 20
    }

cfg = Config()
if not os.path.exists(cfg.MODEL_DIR): os.makedirs(cfg.MODEL_DIR)
np.random.seed(42); random.seed(42)

def log(msg): print(f"[INFO] {time.strftime('%H:%M:%S')} - {msg}")
print("✅ Config Loaded.")

# %%
# ====================================================================
# 2. DATA LOADING & PRE-PROCESSING (Label First -> Sensor Last)
# ====================================================================
def load_and_prep_data():
    log("Scanning & Loading All Data...")
    files = glob.glob(os.path.join(cfg.DATA_DIR, "*.csv"))
    if not files: files = glob.glob(os.path.join(cfg.DATA_DIR, "**/*.csv"), recursive=True)
    
    dfs = []
    for f in files:
        try:
            df = pd.read_csv(f)
            df.columns = [str(c).lower().strip().replace('.1', '') for c in df.columns]
            
            rename_map = {
                'temperature':'temp', 'hum':'humi', 'humidity':'humi', 
                'devid':'devID', 'time':'timestamp', 'date':'timestamp'
            }
            new_cols = {c: rename_map[c] for c in df.columns if c in rename_map}
            if new_cols: df = df.rename(columns=new_cols)
            
            dfs.append(df)
            print(f"   + Loaded: {os.path.basename(f)} | Rows: {len(df)}")
        except Exception as e: 
            print(f"   ! Error loading {f}: {e}")
            
    if not dfs: return None
    
    full_df = pd.concat(dfs, ignore_index=True)
    
    # Clean & Sort
    if 'timestamp' in full_df.columns:
        full_df['timestamp'] = pd.to_datetime(full_df['timestamp'], errors='coerce')
        full_df = full_df.dropna(subset=['timestamp'])

    if 'devID' in full_df.columns and 'timestamp' in full_df.columns:
        full_df = full_df.sort_values(by=['devID', 'timestamp'], ascending=[True, True])
    
    # -----------------------------------------------------------
    # STEP 1: LABEL HANDLING 
    # -----------------------------------------------------------
    log("Processing Labels...")
    if cfg.LABEL_COL in full_df.columns:
        # A. เติม Null เป็น 'normal' ทันที
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].fillna('normal') 
        
        # B. แปลงเป็น String และ clean
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].astype(str).str.lower().str.strip()
        
        # C. จัดการ Text แปลกๆ ที่อาจหลุดมา
        full_df.loc[full_df[cfg.LABEL_COL] == '', cfg.LABEL_COL] = 'normal'
        full_df.loc[full_df[cfg.LABEL_COL] == 'nan', cfg.LABEL_COL] = 'normal'
        
        # D. Map เป็นตัวเลข 0, 1, 2
        full_df[cfg.LABEL_COL] = full_df[cfg.LABEL_COL].map(cfg.LABEL_MAP).fillna(0).astype(int)
    else:
        full_df[cfg.LABEL_COL] = 0

    # -----------------------------------------------------------
    # STEP 2: SENSOR IMPUTATION 
    # -----------------------------------------------------------
    log("Imputing Sensors (Forward & Backward Fill)...")
    
    # เลือกเฉพาะ Column ที่ไม่ใช่ Key (devID, timestamp) และไม่ใช่ Label
    cols_to_fill = [c for c in full_df.columns if c not in ['devID', 'timestamp', cfg.LABEL_COL]]
    
    if 'devID' in full_df.columns:
        # Assign กลับไปเฉพาะ Column ที่เลือก (devID จะไม่หาย)
        full_df[cols_to_fill] = full_df.groupby('devID')[cols_to_fill].ffill()
        full_df[cols_to_fill] = full_df.groupby('devID')[cols_to_fill].bfill()
    
    # Fallback: ถ้ายังมี NaN เหลือ ให้เติม 0
    full_df = full_df.fillna(0)
        
    return full_df.reset_index(drop=True)

# %%
# ====================================================================
# 3. STRATIFIED SPLIT
# ====================================================================
def prepare_data_pipeline(df, feature_cols, horizon=0):
    log(f"Preparing Data Pipeline (Horizon: {horizon})...")
    df_work = df.copy()

    # 1. Create Target
    if horizon > 0:
        df_work['target'] = df_work.groupby('devID')[cfg.LABEL_COL].shift(-horizon)
    else:
        df_work['target'] = df_work[cfg.LABEL_COL]
        
    df_work = df_work.dropna(subset=['target'])
    
    # 2. STRATIFIED SPLIT
    valid_feats = [c for c in feature_cols if c in df_work.columns]
    X = df_work[valid_feats].values
    y = df_work['target'].astype(int).values
    
    # Split 80/10/10
    X_temp, X_test, y_temp, y_test = train_test_split(
        X, y, test_size=0.10, stratify=y, random_state=42
    )
    
    X_train, X_val, y_train, y_val = train_test_split(
        X_temp, y_temp, test_size=0.10, stratify=y_temp, random_state=42
    )
    
    print(f"\n📊 --- Stratified Split Stats (Horizon +{horizon}) ---")
    def print_count(name, y_data):
        c = Counter(y_data)
        print(f"   📌 {name:10s} | Rows: {len(y_data):<6} | 0: {c[0]:<5} 1: {c[1]:<5} 2: {c[2]:<5}")

    print_count("TRAIN", y_train)
    print_count("VAL", y_val)
    print_count("TEST", y_test)
    
    return X_train, y_train, X_val, y_val, X_test, y_test

def balance_training_data(X_train, y_train):
    log("Applying Balancing to TRAIN set...")
    X_bal, y_bal = [], []
    for cls in np.unique(y_train):
        indices = np.where(y_train == cls)[0]
        count = len(indices)
        target = cfg.TARGET_SAMPLES
        if count == 0: continue
        
        if cls == 0 and count > target:
             chosen = np.random.choice(indices, target, replace=False)
        elif count < target:
             chosen = np.random.choice(indices, target, replace=True)
        else:
             chosen = indices
             
        X_bal.append(X_train[chosen])
        y_bal.append(y_train[chosen])
    
    X_bal = np.concatenate(X_bal)
    y_bal = np.concatenate(y_bal)
    
    perm = np.random.permutation(len(X_bal))
    return X_bal[perm], y_bal[perm]

# %%
# ====================================================================
# 4. VISUALIZATION & SHAP
# ====================================================================
def evaluate_set(y_true, y_pred, title):
    print(f"\n{'='*20} {title} {'='*20}")
    print(classification_report(y_true, y_pred, target_names=['Normal', 'Warning', 'Critical'], zero_division=0))
    
    cm = confusion_matrix(y_true, y_pred, labels=[0, 1, 2])
    plt.figure(figsize=(5, 4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Normal', 'Warning', 'Critical'],
                yticklabels=['Normal', 'Warning', 'Critical'])
    plt.title(f"Confusion Matrix: {title}")
    plt.ylabel('Actual'); plt.xlabel('Predicted')
    plt.show()

def plot_feature_importance(model, feature_names):
    try:
        importance = model.feature_importances_
        fi_df = pd.DataFrame({'feature': feature_names, 'importance': importance})
        fi_df = fi_df.sort_values(by='importance', ascending=False).head(20)
        
        plt.figure(figsize=(10, 6))
        sns.barplot(x='importance', y='feature', data=fi_df, palette='viridis')
        plt.title('Top 20 Feature Importance (XGBoost Native)')
        plt.tight_layout()
        plt.show()
    except: pass

def run_shap_analysis(model, X_sample, feature_names, title_suffix=""):
    print(f"\n🧠 Running SHAP Analysis ({title_suffix})...")
    X_df = pd.DataFrame(X_sample, columns=feature_names)
    explainer = shap.TreeExplainer(model)
    shap_values = explainer.shap_values(X_df)
    
    plt.figure()
    shap.summary_plot(shap_values, X_df, plot_type="bar", show=False)
    plt.title(f"SHAP Global Importance - {title_suffix}")
    plt.show()
    
    if isinstance(shap_values, list) and len(shap_values) > 2:
        plt.figure()
        shap.summary_plot(shap_values[2], X_df, show=False)
        plt.title(f"SHAP Values (Critical Class) - {title_suffix}")
        plt.show()
    else:
        plt.figure()
        shap.summary_plot(shap_values, X_df, show=False)
        plt.show()

# ====================================================================
# 5. OPTIMIZATION 
# ====================================================================
def objective(trial, X_tr, y_tr, X_val, y_val):
    params = {
        'n_estimators': trial.suggest_int('n_estimators', 200, 500),
        'learning_rate': trial.suggest_float('learning_rate', 0.01, 0.2, log=True),
        'max_depth': trial.suggest_int('max_depth', 3, 10),
        'subsample': trial.suggest_float('subsample', 0.6, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.6, 1.0),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 10),
        'gamma': trial.suggest_float('gamma', 0, 5)
    }
    model = xgb.XGBClassifier(**cfg.XGB_FIXED, **params)
    model.fit(X_tr, y_tr, eval_set=[(X_val, y_val)], verbose=False)
    preds = model.predict(X_val)
    return f1_score(y_val, preds, average='macro', zero_division=0)

# %%
# ====================================================================
# 6. MAIN EXECUTION
# ====================================================================
def main():
    # 1. Load Data
    df_raw = load_and_prep_data()
    if df_raw is None: return

    if not cfg.FEATURE_COLS:
        cfg.FEATURE_COLS = [c for c in df_raw.columns if c not in [cfg.LABEL_COL, 'timestamp', 'devID', 'target', 'is_test']]
    print(f"👉 Features Used: {len(cfg.FEATURE_COLS)}")
    
    for h in cfg.HORIZONS:
        print(f"\n{'='*50}\n🚀 HORIZON: +{h} Steps\n{'='*50}")
        
        # 2. Split (Stratified)
        X_train_raw, y_train, X_val_raw, y_val, X_test_raw, y_test = prepare_data_pipeline(df_raw, cfg.FEATURE_COLS, h)
        
        if len(X_train_raw) == 0: continue
        
        # 3. Scale (Fit on Train ONLY)
        scaler = StandardScaler()
        X_train_scaled = scaler.fit_transform(X_train_raw)
        X_val_scaled = scaler.transform(X_val_raw)
        X_test_scaled = scaler.transform(X_test_raw)
        
        joblib.dump(scaler, f"{cfg.MODEL_DIR}/scaler_h{h}.save")
        
        # 4. Balance (Train Only)
        X_train_bal, y_train_bal = balance_training_data(X_train_scaled, y_train)
        
        # 5. Optimize
        log(f"Tuning Hyperparameters...")
        optuna.logging.set_verbosity(optuna.logging.WARNING)
        study = optuna.create_study(direction='maximize')
        study.optimize(lambda t: objective(t, X_train_bal, y_train_bal, X_val_scaled, y_val), n_trials=cfg.OPTUNA_TRIALS)
        
        best_params = study.best_params
        print(f"   🏆 Best Params: {best_params}")
        
        # 6. Final Train
        final_model = xgb.XGBClassifier(**cfg.XGB_FIXED, **best_params)
        final_model.fit(X_train_bal, y_train_bal, eval_set=[(X_val_scaled, y_val)], verbose=False)
        final_model.save_model(os.path.join(cfg.MODEL_DIR, f"xgb_strat_h{h}.json"))
        
        # 7. Evaluate
        print("\n🔎 Evaluating TRAIN Set (Balanced)...")
        evaluate_set(y_train_bal, final_model.predict(X_train_bal), f"TRAIN - H{h}")

        print("\n🔎 Evaluating VALIDATION Set...")
        evaluate_set(y_val, final_model.predict(X_val_scaled), f"VAL - H{h}")

        print("\n🔎 Evaluating TEST Set...")
        evaluate_set(y_test, final_model.predict(X_test_scaled), f"TEST - H{h}")
        
        # 8. Feature Importance & SHAP
        plot_feature_importance(final_model, cfg.FEATURE_COLS)
        
        shap_sample_size = min(500, len(X_test_scaled))
        if shap_sample_size > 0:
            idx = np.random.choice(len(X_test_scaled), shap_sample_size, replace=False)
            run_shap_analysis(final_model, X_test_scaled[idx], cfg.FEATURE_COLS, title_suffix=f"H{h}")

    print("\n✅ Process Completed.")

if __name__ == "__main__":
    main()
# Out:
# ✅ Config Loaded.
# [INFO] 16:46:46 - Scanning & Loading All Data...
#    + Loaded: label_105_ma_prepared_with_soil_texture.csv | Rows: 20777
#    + Loaded: label_106_ma_prepared_with_soil_texture.csv | Rows: 36593
#    + Loaded: label_107_ma_prepared_with_soil_texture.csv | Rows: 27096
#    + Loaded: label_108_ma_prepared_with_soil_texture.csv | Rows: 37817
#    + Loaded: label_109_ma_prepared_with_soil_texture.csv | Rows: 26636
# [INFO] 16:46:47 - Processing Labels...
# [INFO] 16:46:47 - Imputing Sensors (Forward & Backward Fill)...
# 👉 Features Used: 26
#
# ==================================================
# 🚀 HORIZON: +0 Steps
# ==================================================
# [INFO] 16:46:47 - Preparing Data Pipeline (Horizon: 0)...
#
# 📊 --- Stratified Split Stats (Horizon +0) ---
#    📌 TRAIN      | Rows: 120624 | 0: 114489 1: 5610  2: 525
#    📌 VAL        | Rows: 13403  | 0: 12722 1: 623   2: 58
#    📌 TEST       | Rows: 14892  | 0: 14134 1: 693   2: 65
# [INFO] 16:46:48 - Applying Balancing to TRAIN set...
# [INFO] 16:46:48 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 384, 'learning_rate': 0.05889937585923574, 'max_depth': 9, 'subsample': 0.7494940418901077, 'colsample_bytree': 0.8902869893531801, 'min_child_weight': 2, 'gamma': 0.31033311225682336}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     12722
#      Warning       0.91      0.99      0.95       623
#     Critical       0.95      0.95      0.95        58
#
#     accuracy                           1.00     13403
#    macro avg       0.95      0.98      0.97     13403
# weighted avg       1.00      1.00      1.00     13403
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H0 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     14134
#      Warning       0.89      0.99      0.94       693
#     Critical       0.93      0.98      0.96        65
#
#     accuracy                           0.99     14892
#    macro avg       0.94      0.99      0.96     14892
# weighted avg       0.99      0.99      0.99     14892
# 🧠 Running SHAP Analysis (H0)...
# ==================================================
# 🚀 HORIZON: +30 Steps
# ==================================================
# [INFO] 16:55:03 - Preparing Data Pipeline (Horizon: 30)...
#
# 📊 --- Stratified Split Stats (Horizon +30) ---
#    📌 TRAIN      | Rows: 120502 | 0: 114367 1: 5610  2: 525
#    📌 VAL        | Rows: 13390  | 0: 12709 1: 623   2: 58
#    📌 TEST       | Rows: 14877  | 0: 14119 1: 693   2: 65
# [INFO] 16:55:03 - Applying Balancing to TRAIN set...
# [INFO] 16:55:03 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 201, 'learning_rate': 0.1784555710155712, 'max_depth': 10, 'subsample': 0.9830335117525937, 'colsample_bytree': 0.9919980452081422, 'min_child_weight': 2, 'gamma': 0.01564785299130031}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     12709
#      Warning       0.70      0.97      0.81       623
#     Critical       0.92      0.95      0.93        58
#
#     accuracy                           0.98     13390
#    macro avg       0.87      0.97      0.91     13390
# weighted avg       0.98      0.98      0.98     13390
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H30 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     14119
#      Warning       0.69      0.97      0.81       693
#     Critical       0.90      0.97      0.93        65
#
#     accuracy                           0.98     14877
#    macro avg       0.86      0.97      0.91     14877
# weighted avg       0.98      0.98      0.98     14877
# 🧠 Running SHAP Analysis (H30)...
# ==================================================
# 🚀 HORIZON: +60 Steps
# ==================================================
# [INFO] 16:58:21 - Preparing Data Pipeline (Horizon: 60)...
#
# 📊 --- Stratified Split Stats (Horizon +60) ---
#    📌 TRAIN      | Rows: 120381 | 0: 114246 1: 5610  2: 525
#    📌 VAL        | Rows: 13376  | 0: 12695 1: 623   2: 58
#    📌 TEST       | Rows: 14862  | 0: 14104 1: 693   2: 65
# [INFO] 16:58:21 - Applying Balancing to TRAIN set...
# [INFO] 16:58:21 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 489, 'learning_rate': 0.01083519270444037, 'max_depth': 10, 'subsample': 0.723368129342837, 'colsample_bytree': 0.9970356459425955, 'min_child_weight': 1, 'gamma': 0.0352532980280979}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     12695
#      Warning       0.70      0.96      0.81       623
#     Critical       0.88      0.86      0.87        58
#
#     accuracy                           0.98     13376
#    macro avg       0.86      0.94      0.89     13376
# weighted avg       0.98      0.98      0.98     13376
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H60 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     14104
#      Warning       0.70      0.97      0.82       693
#     Critical       0.83      0.92      0.88        65
#
#     accuracy                           0.98     14862
#    macro avg       0.84      0.96      0.89     14862
# weighted avg       0.98      0.98      0.98     14862
# 🧠 Running SHAP Analysis (H60)...
# ==================================================
# 🚀 HORIZON: +180 Steps
# ==================================================
# [INFO] 17:06:15 - Preparing Data Pipeline (Horizon: 180)...
#
# 📊 --- Stratified Split Stats (Horizon +180) ---
#    📌 TRAIN      | Rows: 119895 | 0: 113760 1: 5610  2: 525
#    📌 VAL        | Rows: 13322  | 0: 12641 1: 623   2: 58
#    📌 TEST       | Rows: 14802  | 0: 14044 1: 693   2: 65
# [INFO] 17:06:15 - Applying Balancing to TRAIN set...
# [INFO] 17:06:15 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 224, 'learning_rate': 0.02385695529281722, 'max_depth': 10, 'subsample': 0.7580843209701954, 'colsample_bytree': 0.6080323772698063, 'min_child_weight': 1, 'gamma': 0.2785784255915482}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     12641
#      Warning       0.74      0.97      0.84       623
#     Critical       0.93      0.97      0.95        58
#
#     accuracy                           0.98     13322
#    macro avg       0.89      0.97      0.93     13322
# weighted avg       0.99      0.98      0.98     13322
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H180 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     14044
#      Warning       0.72      0.97      0.83       693
#     Critical       0.86      0.97      0.91        65
#
#     accuracy                           0.98     14802
#    macro avg       0.86      0.97      0.91     14802
# weighted avg       0.99      0.98      0.98     14802
# 🧠 Running SHAP Analysis (H180)...
# ==================================================
# 🚀 HORIZON: +360 Steps
# ==================================================
# [INFO] 17:10:11 - Preparing Data Pipeline (Horizon: 360)...
#
# 📊 --- Stratified Split Stats (Horizon +360) ---
#    📌 TRAIN      | Rows: 119166 | 0: 113031 1: 5610  2: 525
#    📌 VAL        | Rows: 13241  | 0: 12560 1: 623   2: 58
#    📌 TEST       | Rows: 14712  | 0: 13954 1: 693   2: 65
# [INFO] 17:10:11 - Applying Balancing to TRAIN set...
# [INFO] 17:10:11 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 357, 'learning_rate': 0.08511830546599247, 'max_depth': 9, 'subsample': 0.6556817802568675, 'colsample_bytree': 0.7445706304293123, 'min_child_weight': 4, 'gamma': 0.13964553910693853}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      1.00      1.00     10000
#     Critical       1.00      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     12560
#      Warning       0.73      0.97      0.83       623
#     Critical       0.88      0.97      0.92        58
#
#     accuracy                           0.98     13241
#    macro avg       0.87      0.97      0.91     13241
# weighted avg       0.99      0.98      0.98     13241
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H360 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     13954
#      Warning       0.69      0.97      0.80       693
#     Critical       0.82      0.91      0.86        65
#
#     accuracy                           0.98     14712
#    macro avg       0.84      0.95      0.88     14712
# weighted avg       0.98      0.98      0.98     14712
# 🧠 Running SHAP Analysis (H360)...
# ==================================================
# 🚀 HORIZON: +720 Steps
# ==================================================
# [INFO] 17:15:30 - Preparing Data Pipeline (Horizon: 720)...
#
# 📊 --- Stratified Split Stats (Horizon +720) ---
#    📌 TRAIN      | Rows: 117708 | 0: 111573 1: 5610  2: 525
#    📌 VAL        | Rows: 13079  | 0: 12398 1: 623   2: 58
#    📌 TEST       | Rows: 14532  | 0: 13774 1: 693   2: 65
# [INFO] 17:15:31 - Applying Balancing to TRAIN set...
# [INFO] 17:15:31 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 214, 'learning_rate': 0.18440764453900246, 'max_depth': 7, 'subsample': 0.9087929786503397, 'colsample_bytree': 0.7307284335557975, 'min_child_weight': 3, 'gamma': 0.018806510840767503}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      1.00      1.00     10000
#      Warning       1.00      0.99      1.00     10000
#     Critical       0.99      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     12398
#      Warning       0.73      0.98      0.84       623
#     Critical       0.96      0.93      0.95        58
#
#     accuracy                           0.98     13079
#    macro avg       0.90      0.97      0.93     13079
# weighted avg       0.99      0.98      0.98     13079
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H720 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     13774
#      Warning       0.74      0.96      0.83       693
#     Critical       0.89      0.89      0.89        65
#
#     accuracy                           0.98     14532
#    macro avg       0.88      0.95      0.91     14532
# weighted avg       0.99      0.98      0.98     14532
# 🧠 Running SHAP Analysis (H720)...
# ==================================================
# 🚀 HORIZON: +1440 Steps
# ==================================================
# [INFO] 17:18:38 - Preparing Data Pipeline (Horizon: 1440)...
#
# 📊 --- Stratified Split Stats (Horizon +1440) ---
#    📌 TRAIN      | Rows: 114792 | 0: 108657 1: 5610  2: 525
#    📌 VAL        | Rows: 12755  | 0: 12074 1: 623   2: 58
#    📌 TEST       | Rows: 14172  | 0: 13414 1: 693   2: 65
# [INFO] 17:18:38 - Applying Balancing to TRAIN set...
# [INFO] 17:18:38 - Tuning Hyperparameters...
#    🏆 Best Params: {'n_estimators': 355, 'learning_rate': 0.13068628104619268, 'max_depth': 6, 'subsample': 0.691781096635339, 'colsample_bytree': 0.649074447489187, 'min_child_weight': 4, 'gamma': 0.010861495440357805}
#
# 🔎 Evaluating TRAIN Set (Balanced)...
#
# ==================== TRAIN - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.99      1.00     10000
#      Warning       0.99      0.99      0.99     10000
#     Critical       0.99      1.00      1.00     10000
#
#     accuracy                           1.00     30000
#    macro avg       1.00      1.00      1.00     30000
# weighted avg       1.00      1.00      1.00     30000
# 🔎 Evaluating VALIDATION Set...
#
# ==================== VAL - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     12074
#      Warning       0.74      0.95      0.84       623
#     Critical       0.78      0.93      0.85        58
#
#     accuracy                           0.98     12755
#    macro avg       0.84      0.96      0.89     12755
# weighted avg       0.99      0.98      0.98     12755
# 🔎 Evaluating TEST Set...
#
# ==================== TEST - H1440 ====================
#               precision    recall  f1-score   support
#
#       Normal       1.00      0.98      0.99     13414
#      Warning       0.73      0.96      0.83       693
#     Critical       0.87      0.92      0.90        65
#
#     accuracy                           0.98     14172
#    macro avg       0.87      0.96      0.91     14172
# weighted avg       0.99      0.98      0.98     14172
# 🧠 Running SHAP Analysis (H1440)...
# ✅ Process Completed.
